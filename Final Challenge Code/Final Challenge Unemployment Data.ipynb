# %% [markdown]
# # Part 1
#
# Part 1 is just using sample/test coding to figure out the process that will need to be followed in order to process all 50 state data in a single for loop statement.

# %%
# Importing my dependencies which is only pandas
import pandas as pd

#Creating a DataFrame using the read_excel function from pandas
df = pd.read_excel("/Users/origi/Documents/Data Bootcamp/Final Challenge/Small Folder/Alabama.xlsx")

#Showing 100 points of data from the DataFrame
df.head(100)
# Out:
#    Local Area Unemployment Statistics  \
# 0                 Original Data Value
# 1                                 NaN
# 2                          Series Id:
# 3                 Seasonally Adjusted
# 4                               Area:
# 5                          Area Type:
# 6              State/Region/Division:
# 7                              Years:
# 8                                 NaN
# 9                                Year
# 10                               2020
# 11                               2020
# 12                               2020
# 13                               2020
# 14                               2020
# 15                               2020
# 16                               2020
# 17                               2020
# 18                               2020
# 19                               2020
# 20                               2020
# 21                               2020
# 22                               2021
# ...

# %%
#Isolating the rows and information that is desired from the excel file
Alabama_df = df.iloc[10:]

#Showing 10 data points from the DataFrame to make sure that the desired results were achieved
Alabama_df.head(10)
# Out:
#    Local Area Unemployment Statistics Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 10                               2020        Jan       57.5       55.6
# 11                               2020        Feb       57.4       55.4
# 12                               2020        Mar       57.2       55.2
# 13                               2020        Apr       55.4       47.8
# 14                               2020        May       57.4       51.5
# 15                               2020        Jun       57.5       52.5
# 16                               2020        Jul       57.8       53.4
# 17                               2020        Aug       57.7       53.9
# 18                               2020        Sep       57.8       54.3
# 19                               2020        Oct       57.5       54.5
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 10    2271707    2196647      75060        3.3
# 11    2266396    2188425      77971        3.4
# ...

# %%
# The desired column names instead of "Local Area Unemployment Statistics", "Unnamed: 1",..., etc.
Column_names = ["Year", "Period", "Labor Force Participation Rate", "Employment-Population Ratio", "Labor Force", "Employment", "Unemployment", "Unemployment Rate"]

# %%
# Applying the column names to the DataFrame
Alabama = Alabama_df.set_axis(Column_names, axis=1, inplace=False)

# Appyling a caption just for aesthetic appeal
Alabama.style.set_table_attributes("style='display:inline'").set_caption('Alabama')
# Out:
# <style  type="text/css" >
# </style><table id="T_8817a282_3896_11ed_9907_868e52611a8d" style='display:inline'><caption>Alabama</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Year</th>        <th class="col_heading level0 col1" >Period</th>        <th class="col_heading level0 col2" >Labor Force Participation Rate</th>        <th class="col_heading level0 col3" >Employment-Population Ratio</th>        <th class="col_heading level0 col4" >Labor Force</th>        <th class="col_heading level0 col5" >Employment</th>        <th class="col_heading level0 col6" >Unemployment</th>        <th class="col_heading level0 col7" >Unemployment Rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8817a282_3896_11ed_9907_868e52611a8dlevel0_row0" class="row_heading level0 row0" >10</th>
#                         <td id="T_8817a282_3896_11ed_9907_868e52611a8drow0_col0" class="data row0 col0" >2020</td>
# ...

# %% [markdown]
# # Part 2
#
# Part 2 is just the combination of the dummy/test code from above and shoving it into a for loop in order to avoid having to manually input each state through the code above.

# %%
# The list of states that the for loop will iterate for
State_names = ["Alaska", "Alabama", "Arkansas", "Arizona", "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Iowa", "Idaho", "Illinois", "Indiana", "Kansas", "Kentucky", "Louisiana", "Massachusetts", "Maryland", "Maine", "Michigan", "Minnesota", "Missouri", "Mississippi", "Montana", "North_Carolina", "North_Dakota", "Nebraska", "New_Hampshire", "New_Jersey", "New_Mexico", "Nevada", "New_York", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode_Island", "South_Carolina", "South_Dakota", "Tennessee", "Texas", "Utah", "Virginia", "Vermont", "Washington", "Wisconsin", "West_Virginia", "Wyoming"]

# %%
# Reaffirming the desired column names
Column_names = ["Year", "Period", "Labor Force Participation Rate", "Employment-Population Ratio", "Labor Force", "Employment", "Unemployment", "Unemployment Rate"] 

# For loop designed to iterate through the State_names array and apply the desired changes to each of the states unemployment data
for i in State_names:
    # Reading the states excel file it
    df = pd.read_excel("/Users/origi/Documents/Data Bootcamp/Final Challenge/Small Folder/"+i+".xlsx")
    i_opt = df.iloc[10:]
    i_df = i_opt.set_axis(Column_names, axis=1, inplace=False)
    i_df.style.set_table_attributes("style='display:inline'").set_caption('i')
    # Create the output file (CSV).
    output_data_file = "/Users/origi/Documents/Data Bootcamp/Final Challenge/Preprocessed Small Folder/"+i+".csv"
    # Export the City_Data into a CSV.
    i_df.to_csv(output_data_file)
